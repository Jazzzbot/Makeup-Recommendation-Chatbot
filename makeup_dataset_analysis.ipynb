# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cosmetic_df=pd.read_csv("cosmetics.csv")

# %%
cosmetic_df.head()
# Out:
#          Label           Brand                                           Name  \
# 0  Moisturizer          LA MER                                Crème de la Mer
# 1  Moisturizer           SK-II                       Facial Treatment Essence
# 2  Moisturizer  DRUNK ELEPHANT                     Protini™ Polypeptide Cream
# 3  Moisturizer          LA MER                    The Moisturizing Soft Cream
# 4  Moisturizer    IT COSMETICS  Your Skin But Better™ CC+™ Cream with SPF 50+
#
#    Price  Rank                                        Ingredients  \
# 0    175   4.1  Algae (Seaweed) Extract, Mineral Oil, Petrolat...
# 1    179   4.1  Galactomyces Ferment Filtrate (Pitera), Butyle...
# 2     68   4.4  Water, Dicaprylyl Carbonate, Glycerin, Ceteary...
# 3    175   3.8  Algae (Seaweed) Extract, Cyclopentasiloxane, P...
# 4     38   4.1  Water, Snail Secretion Filtrate, Phenyl Trimet...
#
#    Combination  Dry  Normal  Oily  Sensitive
# 0            1    1       1     1          1
# ...

# %%
cosmetic_df.describe(include='all')
# Out:
#               Label     Brand             Name        Price         Rank  \
# count          1472      1472             1472  1472.000000  1472.000000
# unique            6       116             1472          NaN          NaN
# top     Moisturizer  CLINIQUE  Crème de la Mer          NaN          NaN
# freq            298        79                1          NaN          NaN
# mean            NaN       NaN              NaN    55.584239     4.153261
# std             NaN       NaN              NaN    45.014429     0.633918
# min             NaN       NaN              NaN     3.000000     0.000000
# 25%             NaN       NaN              NaN    30.000000     4.000000
# 50%             NaN       NaN              NaN    42.500000     4.300000
# 75%             NaN       NaN              NaN    68.000000     4.500000
# max             NaN       NaN              NaN   370.000000     5.000000
#
#        Ingredients  Combination          Dry       Normal         Oily  \
# ...

# %%
cosmetic_df.min(numeric_only=True)
cosmetic_df.max(numeric_only=True)
cosmetic_df.median(numeric_only=True)
# Out:
# Price          42.5
# Rank            4.3
# Combination     1.0
# Dry             1.0
# Normal          1.0
# Oily            1.0
# Sensitive       1.0
# dtype: float64

# %%
cosmetic_df.corr(numeric_only=True)
# Out:
#                 Price      Rank  Combination       Dry    Normal      Oily  \
# Price        1.000000 -0.025215     0.012575  0.065525  0.049230  0.003978
# Rank        -0.025215  1.000000     0.036904  0.026982  0.051926  0.021041
# Combination  0.012575  0.036904     1.000000  0.830784  0.927966  0.882528
# Dry          0.065525  0.026982     0.830784  1.000000  0.874436  0.745767
# Normal       0.049230  0.051926     0.927966  0.874436  1.000000  0.835227
# Oily         0.003978  0.021041     0.882528  0.745767  0.835227  1.000000
# Sensitive    0.007621  0.015946     0.689316  0.722367  0.713320  0.648097
#
#              Sensitive
# Price         0.007621
# Rank          0.015946
# Combination   0.689316
# Dry           0.722367
# Normal        0.713320
# Oily          0.648097
# Sensitive     1.000000

# %%
sns.heatmap(cosmetic_df.corr(numeric_only=True), annot=True)
plt.show()
